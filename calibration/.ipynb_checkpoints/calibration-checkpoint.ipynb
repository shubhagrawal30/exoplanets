# %%
import numpy as np
import astropy.units as u
import matplotlib.pyplot as plt
import calibration
from importlib import reload
calibration = reload(calibration)
from scipy.optimize import curve_fit
from copy import copy
from itertools import repeat

# %%
OH_lines_file = open("./list_v2.0.dat", 'r')
OH_lines = [x for x in OH_lines_file.readlines() if x[0] != "#"]
OH_wavelengths = np.array([]) * u.angstrom
OH_intensity = np.array([])
for line in OH_lines:
    walen, inten = line.split()
    OH_wavelengths = np.append(OH_wavelengths, float(walen) * u.angstrom)
    OH_intensity = np.append(OH_intensity, float(inten))

# %%
# %matplotlib notebook 
plt.plot(OH_wavelengths, OH_intensity)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
R = 4000
data = calibration.read_osiris("./reduced_sky_jb/s161106_a024002_Kbb_020.fits")

# %%
wavs = data[0] * u.micron
wav_low, wav_high = np.min(wavs), np.max(wavs)

# %%
sky_model = np.zeros_like(wavs.value)

# %%
def gaussian1D(Xs, wavelength, fwhm):
    sig = fwhm / (2 * np.sqrt(2 * np.log(2)))
    mu = wavelength
    gauss = np.exp(- (Xs - mu) ** 2 / (2 * sig * sig))
    return gauss / (sig * np.sqrt(2 * np.pi))

# %%
c = 0
for i, wav in enumerate(OH_wavelengths):
    if wav_low <= wav <= wav_high:
        c += (OH_intensity[i] > 0.1 * np.max(OH_intensity))
        fwhm = wav / 4000
        sky_model += OH_intensity[i] * \
                    (gaussian1D(wavs, wav, fwhm) * (wavs[1]-wavs[0])).to('').value  
print(c)
# Out:
# 26

# %%
# %matplotlib notebook 
plt.plot(wavs, sky_model)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cube = data[1]

# %%
cube.shape, len(wavs)
# Out:
# ((1665, 64, 19), 1665)

# %%
# one_pixel = np.mean(np.mean(cube, axis=2), axis=1)
one_pixel = cube[:, 30, 10]
np.shape(one_pixel)
# Out:
# (1665,)

# %%
# %matplotlib notebook 
plt.plot(wavs, one_pixel)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook 
plt.plot(wavs, one_pixel)
plt.plot(wavs, wrapper(wavs.value, np.max(one_pixel) * 1e-3, 0, 1.5, -6, 6))
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0.0004097518026828766 0 1.5 -6 6

# %%
def wrapper(wavs, G, offset, a, b, c):
    print(G, offset, a, b, c)
    wavs = copy(wavs) * u.micron        
    sky_model = np.zeros_like(wavs.value)
    for i, wav in enumerate(OH_wavelengths):
        if wav_low <= wav <= wav_high:
            fwhm = wav / 4000
            sky_model += OH_intensity[i] * \
                        (gaussian1D(wavs, wav+offset*u.nm, fwhm) * (wavs[1]-wavs[0])).to('').value  
    return G * sky_model + (a * (wavs.value ** 2) + b * wavs.value + c)

# %%
p0, _ = curve_fit(wrapper, wavs, one_pixel, p0=(2e-4, 0, 1.5, -6, 6))
# Out:
# 0.0002 0.0 1.5 -6.0 6.0
# 0.0002 0.0 1.5 -6.0 6.0
# 0.0002 0.0 1.5 -6.0 6.0
# 0.00020000000298023225 0.0 1.5 -6.0 6.0
# 0.0002 1.4901161193880158e-08 1.5 -6.0 6.0
# 0.0002 0.0 1.5000000223517418 -6.0 6.0
# 0.0002 0.0 1.5 -5.999999910593033 6.0
# 0.0002 0.0 1.5 -6.0 6.000000089406967
# 0.00023605612351988345 0.052617295510526144 1.9285798772703773 -7.845488888165063 7.993142762013634
# 0.0002360561270373938 0.052617295510526144 1.9285798772703773 -7.845488888165063 7.993142762013634
# 0.00023605612351988345 0.05261729629458495 1.9285798772703773 -7.845488888165063 7.993142762013634
# 0.00023605612351988345 0.052617295510526144 1.928579906008457 -7.845488888165063 7.993142762013634
# 0.00023605612351988345 0.052617295510526144 1.9285798772703773 -7.845488771258168 7.993142762013634
# 0.00023605612351988345 0.052617295510526144 1.9285798772703773 -7.845488888165063 7.993142881120743
# 0.0002384841194849381 0.04489517492444023 1.928443258695409 -7.844500125607321 7.991576924018784
# 0.0002384841230386284 0.04489517492444023 1.928443258695409 -7.844500125607321 7.991576924018784
# 0.0002384841194849381 0.04489517559343047 1.928443258695409 -7.844500125607321 7.991576924018784
# 0.0002384841194849381 0.04489517492444023 1.9284432874314528 -7.844500125607321 7.991576924018784
# 0.0002384841194849381 0.04489517492444023 1.928443258695409 -7.84450000871516 7.991576924018784
# 0.0002384841194849381 0.04489517492444023 1.928443258695409 -7.844500125607321 7.99157704310256
# 0.00023855876563156966 0.04484750670220151 1.928437880737138 -7.844464547169486 7.991523106204068
# 0.00023855876918637227 0.04484750670220151 1.928437880737138 -7.844464547169486 7.991523106204068
# 0.00023855876563156966 0.04484750737048143 1.928437880737138 -7.844464547169486 7.991523106204068
# 0.00023855876563156966 0.04484750670220151 1.9284379094731017 -7.844464547169486 7.991523106204068
# 0.00023855876563156966 0.04484750670220151 1.928437880737138 -7.8444644302778554 7.991523106204068
# 0.00023855876563156966 0.04484750670220151 1.928437880737138 -7.844464547169486 7.991523225287041
# 0.00023855876793591282 0.04484675183813643 1.92843785265315 -7.8444644245616 7.991522972732277
# 0.00023855877149071548 0.04484675183813643 1.92843785265315 -7.8444644245616 7.991522972732277
# 0.00023855876793591282 0.04484675250640511 1.92843785265315 -7.8444644245616 7.991522972732277
# 0.00023855876793591282 0.04484675183813643 1.9284378813891134 -7.8444644245616 7.991522972732277
# 0.00023855876793591282 0.04484675183813643 1.92843785265315 -7.844464307669972 7.991522972732277
# 0.00023855876793591282 0.04484675183813643 1.92843785265315 -7.8444644245616 7.991523091815249
# 0.00023855876729913855 0.044845283670316614 1.9284378850405917 -7.844464564806128 7.991523124101597

# %%
# %matplotlib notebook 
plt.plot(wavs, one_pixel)
plt.plot(wavs, wrapper(wavs.value, *p0))
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0.00023855876729913855 0.044845283670316614 1.9284378850405917 -7.844464564806128 7.991523124101597

# %%
p0[1] * u.nm
# Out:
# <Quantity 0.0444225 nm>

# %%
# %matplotlib notebook
roll_avg = np.zeros_like(one_pixel)
w = len(one_pixel) // 20
for i in range(len(one_pixel)):
    roll_avg[i] = np.mean(one_pixel[i: i+w])
plt.plot(wavs, roll_avg)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
p0 = np.polyfit(wavs, roll_avg, deg=2)
plt.plot(wavs, roll_avg)
plt.plot(wavs, np.polyval(p0, wavs.value))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
p0
# Out:
# array([ 2.00575179, -8.17743093,  8.36094365])

# %%
np.transpose(np.vstack([sky_model, wavs.value, np.ones_like(wavs.value)])).shape
# Out:
# (1665, 3)

# %%
def sky_model_linear_parameters(wavs_val, sky_model, one_pixel):
    A = np.transpose(np.vstack([sky_model, wavs_val ** 2, wavs_val, np.ones_like(wavs_val)]))
    b = one_pixel
    return lsq_linear(A, b)

# %%
from scipy.optimize import lsq_linear
sky_model_linear_parameters(wavs.value, sky_model, one_pixel)
# Out:
#  active_mask: array([0., 0., 0., 0.])
#         cost: 0.33344663531145236
#          fun: array([-0.00433185,  0.00266573, -0.00351411, ..., -0.00579836,
#        -0.00878161, -0.01077481])
#      message: 'The unconstrained solution is optimal.'
#          nit: 0
#   optimality: 9.6122151752899e-10
#       status: 3
#      success: True
#            x: array([ 2.36003125e-04,  1.92828601e+00, -7.84420109e+00,  7.99173763e+00])

# %%
repeanp.arange(5) * np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])
